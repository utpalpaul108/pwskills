# %% [markdown]
# ## Assignment On Matplotlib

# %% [markdown]
# **Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.**

# %% [markdown]
# Matplotlib is a data visualization library for Python. It is used to create a wide variety of visualizations, including line plots, scatter plots, bar plots, histograms, heatmaps, and more. Matplotlib provides a flexible and powerful interface for creating high-quality visualizations in Python.
#
# Here are five plots that can be plotted using the pyplot module of Matplotlib:
#
# * **Line plot:** A line plot is a plot that displays data points connected by straight line segments. It is used to show the trend of a variable over time or to compare two or more variables.
#
# * **Scatter plot:** A scatter plot is a plot that displays the relationship between two variables as a set of points on a two-dimensional plane. It is used to investigate the correlation between two variables or to identify outliers.
#
# * **Bar plot:** A bar plot is a plot that displays the distribution of a categorical variable using bars. It is used to compare the frequency or proportion of different categories.
#
# * **Histogram:** A histogram is a plot that displays the distribution of a continuous variable using bars. It is used to show the shape of the distribution and to identify outliers.
#
# * **Heatmap:** A heatmap is a plot that displays the relationship between two variables as a color-coded matrix. It is used to visualize patterns in large datasets or to identify correlations between variables.

# %% [markdown]
# **Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.**

# %% [markdown]
# A scatter plot is a type of plot used to display the relationship between two continuous variables. Each point on the plot represents a pair of values for the two variables, with the x-axis usually representing the independent variable and the y-axis representing the dependent variable. Scatter plots are useful for identifying patterns or relationships between two variables and for detecting outliers or unusual observations.
#
# Scatter plots are commonly used in many fields, including science, engineering, finance, and social sciences. They can be used to explore and analyze data, as well as to communicate findings and insights to others.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

plt.scatter(x,y, c="b")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.title("Scatter Plot of X Vs Y")
plt.show()

# %% [markdown]
# **Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.**

# %% [markdown]
# The **subplot()** function in Matplotlib is used to create multiple plots in a single figure. It allows us to arrange multiple plots in a grid-like structure, where each plot represents a different aspect of the data. The **subplot()** function takes three arguments: nrows, ncols, and index. These arguments specify the number of rows and columns in the grid of plots and the index of the plot that we want to create.

# %%
plt.figure(figsize=(10,4))

# For Line 1
x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])

plt.subplot(2,2,1)
plt.plot(x1,y1)
plt.title("Line 1")

# For Line 2
x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])

plt.subplot(2,2,2)
plt.plot(x1,y1)
plt.title("Line 2")

# For Line 3
x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])

plt.subplot(2,2,3)
plt.plot(x1,y1)
plt.title("Line 3")

# For Line 4
x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])

plt.subplot(2,2,4)
plt.plot(x4,y4)
plt.title("Line 4")
plt.show()

# %% [markdown]
# **Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.**

# %% [markdown]
# A bar plot, also known as a bar chart, is a graphical representation of categorical data using rectangular bars. The height or length of each bar represents the frequency or value of the corresponding category. Bar plots are used to compare and visualize the distribution of different categories in a dataset.
#
# Bar plots are particularly useful for displaying discrete or categorical data, such as survey responses, demographic information, or sales data by product category. They can also be used to show changes in data over time, such as monthly sales or stock prices.

# %%
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# Plot Bar Plot
plt.figure(figsize=(5,3))
plt.bar(company,profit, color="b")
plt.xlabel("Company")
plt.ylabel("Profit")
plt.title("Bar Plot of Company Vs Profit")
plt.show()

# %%
# Horizontal Bar Plot
plt.figure(figsize=(5,3))
plt.barh(company,profit, color="b")
plt.xlabel("Company")
plt.ylabel("Profit")
plt.title("Bar Plot of Company Vs Profit")
plt.show()

# %% [markdown]
# **Q5: What is a box plot? Why is it used? Using the following data plot a box plot.**

# %% [markdown]
# A box plot, also known as a box-and-whisker plot, is a graphical representation of a dataset that displays the distribution of the data based on five summary statistics: the minimum value, the first quartile (25th percentile), the median (50th percentile), the third quartile (75th percentile), and the maximum value. The box in the middle of the plot represents the interquartile range (IQR), which is the range between the first and third quartiles. The whiskers extend from the box to the minimum and maximum values, but may be defined in different ways depending on the implementation.
#
# Box plots are used to visually summarize and compare the distribution of a dataset, especially when the dataset contains outliers or is skewed. They provide a quick and simple way to understand the range and distribution of a dataset without having to look at individual data points.

# %%
plt.figure(figsize=(6,3))
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

plt.boxplot([box1, box2],labels=["Box-1","Box-2"])
plt.title("Box Plot")
plt.show()
